# %% [markdown]
# # 🧹✨ TASK 03 — DATA CLEANING & MANIPULATION
#
# ### 🐼 Python • Pandas • NumPy
#
# > **Transforming Dirty E-Commerce Data into Clean, Reliable & Analysis-Ready Data**
#
# ---
#
# 📌 **Project:** Data Cleaning & Manipulation
# 🐍 **Language:** Python
# 📚 **Libraries:** Pandas, NumPy
# 🗂️ **Dataset:** Dirty E-Commerce Dataset
# 🎯 **Goal:** Clean, validate and transform raw data for further analysis
#
# ---
#
# ### 🚀 PROJECT WORKFLOW
#
# **Raw Data** → 🕵️ **Data Inspection** → 🧹 **Cleaning** → 🔧 **Transformation** → ✅ **Validation** → 📊 **Before vs After** → 💾 **Clean CSV**
#
# ---

# %% [markdown]
# ## Libraries import

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Dataset load

# %%
df = pd.read_csv("dirty_ecommerce_dataset.csv")

# %%
df.head(5)
# Out:
#    Order_ID Customer_ID Customer_Name       City  Order_Date Product_Category  \
# 0  ORD10001    CUST1001    Customer_1        NaN  01-01-2025           Sports
# 1  ORD10002    CUST1002    Customer_2  Ghaziabad  01-01-2025      Electronics
# 2  ORD10003    CUST1003    Customer_3  Faridabad  02-01-2025      Electronics
# 3  ORD10004    CUST1004    Customer_4    Lucknow  02-01-2025      Electronics
# 4  ORD10005    CUST1005    Customer_5    Gurgaon  03-01-2025          Grocery
#
#    Quantity Unit_Price  Discount    Payment_Method Order_Status  \
# 0         5    11202.0        15       Net Banking     Returned
# 1         3     9718.0        20  Cash on Delivery      Shipped
# 2         5    13458.0         0       Net Banking    Delivered
# 3         2     1219.0         0        Debit Card     Returned
# 4         1     5437.0         0  Cash on Delivery    Delivered
#
#    Customer_Rating  Delivery_Days  Total_Amount
# 0              1.0            6.0       47608.5
# ...

# %% [markdown]
# ## BEFORE CLEANING analysis

# %%
#Dataset size,Column names,Data types

Shape= df.shape
print("Shape=",Shape)

print("----------------------------------------------------------------------------------------")

Columns= df.columns
print("Columns=",Columns)

print("----------------------------------------------------------------------------------------")

Info= df.info()
print("Info",Info)
# Out:
# Shape= (1010, 14)
# ----------------------------------------------------------------------------------------
# Columns= Index(['Order_ID', 'Customer_ID', 'Customer_Name', 'City', 'Order_Date',
#        'Product_Category', 'Quantity', 'Unit_Price', 'Discount',
#        'Payment_Method', 'Order_Status', 'Customer_Rating', 'Delivery_Days',
#        'Total_Amount'],
#       dtype='object')
# ----------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1010 non-null   object
#  1   Customer_ID       1010 non-null   object
#  2   Customer_Name     1010 non-null   object
#  3   City              980 non-null    object
#  4   Order_Date        1010 non-null   object
#  5   Product_Category  1010 non-null   object
# ...

# %%
#Missing values count
df.isnull().sum()
# Out:
# Order_ID             0
# Customer_ID          0
# Customer_Name        0
# City                30
# Order_Date           0
# Product_Category     0
# Quantity             0
# Unit_Price          21
# Discount             0
# Payment_Method      25
# Order_Status         0
# Customer_Rating     51
# Delivery_Days       32
# Total_Amount         0
# dtype: int64

# %%
#Duplicate rows
df.duplicated().sum()
# Out:
# np.int64(8)

# %% [markdown]
# ## Basic statistics

# %%
df.describe()
# Out:
#           Quantity     Discount  Customer_Rating  Delivery_Days  Total_Amount
# count  1010.000000  1010.000000       959.000000     978.000000   1010.000000
# mean      3.047525    12.069307         2.955162       4.383436  20441.178218
# std       1.428757     8.571113         1.430751       2.306861  16303.321403
# min      -2.000000     0.000000         0.000000      -3.000000    331.200000
# 25%       2.000000     5.000000         2.000000       2.000000   6916.350000
# 50%       3.000000    10.000000         3.000000       4.000000  15924.000000
# 75%       4.000000    20.000000         4.000000       6.000000  31218.675000
# max       5.000000    25.000000         7.000000       8.000000  70860.500000

# %% [markdown]
# ## Data Cleaning

# %%
# Remove duplicates
df = df.drop_duplicates()

# %%
# Convert Unit_Price to numeric
df["Unit_Price"] = pd.to_numeric(df["Unit_Price"], errors="coerce")
# Out:
# C:\Users\itzra\AppData\Local\Temp\ipykernel_20368\3740294589.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Unit_Price"] = pd.to_numeric(df["Unit_Price"], errors="coerce")

# %%
df = df.copy()

# %%
df["Unit_Price"] = pd.to_numeric(df["Unit_Price"], errors="coerce")

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"], errors="coerce")

# %% [markdown]
# ## Missing Values filling

# %%
df["Unit_Price"] = df["Unit_Price"].fillna(df["Unit_Price"].median())
df["Customer_Rating"] = df["Customer_Rating"].fillna(df["Customer_Rating"].median())
df["Delivery_Days"] = df["Delivery_Days"].fillna(df["Delivery_Days"].median())

# %%
df["City"] = df["City"].fillna(df["City"].mode()[0])
df["Payment_Method"] = df["Payment_Method"].fillna(df["Payment_Method"].mode()[0])

# %%
# Convert float col to int

for col in df.select_dtypes(include="float").columns:
if df[col].dropna().apply(float.is_integer).all():
df[col] = df[col].astype("Int64")

# %%
df
# Out:
#       Order_ID Customer_ID Customer_Name        City Order_Date  \
# 0     ORD10001    CUST1001    Customer_1   Ghaziabad 2025-01-01
# 1     ORD10002    CUST1002    Customer_2   Ghaziabad 2025-01-01
# 2     ORD10003    CUST1003    Customer_3   Faridabad 2025-02-01
# 3     ORD10004    CUST1004    Customer_4     Lucknow 2025-02-01
# 4     ORD10005    CUST1005    Customer_5     Gurgaon 2025-03-01
# ...        ...         ...           ...         ...        ...
# 997   ORD10998    CUST1298  Customer_298   Ghaziabad        NaT
# 998   ORD10999    CUST1299  Customer_299  Chandigarh        NaT
# 999   ORD11000    CUST1300  Customer_300     Gurgaon        NaT
# 1008  ORD10101    CUST1101  Customer_101      Jaipur        NaT
# 1009  ORD10051    CUST1151  Customer_151     Lucknow 2025-08-09
#
#      Product_Category  Quantity  Unit_Price  Discount    Payment_Method  \
# 0              Sports         5       11202        15       Net Banking
# ...

# %%
raw = pd.read_csv("dirty_ecommerce_dataset.csv")

df["Order_Date"] = pd.to_datetime(
    raw["Order_Date"],
    format="mixed",
    errors="coerce"
)

# %%
df["Order_Date"].isnull().sum()
# Out:
# np.int64(20)

# %%
df["Order_Date"].head()
# Out:
# 0   2025-01-01
# 1   2025-01-01
# 2   2025-02-01
# 3   2025-02-01
# 4   2025-03-01
# Name: Order_Date, dtype: datetime64[ns]

# %%
df.isnull().sum()
# Out:
# Order_ID             0
# Customer_ID          0
# Customer_Name        0
# City                 0
# Order_Date          20
# Product_Category     0
# Quantity             0
# Unit_Price           0
# Discount             0
# Payment_Method       0
# Order_Status         0
# Customer_Rating      0
# Delivery_Days        0
# Total_Amount         0
# dtype: int64

# %%
df["Order_Date"] = df["Order_Date"].ffill()

# %%
df["Order_Date"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df["Price_Category"] = np.where(df["Unit_Price"] >= df["Unit_Price"].median(),"High","Low")

# %% [markdown]
# ## Final Validation

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print("Missing Values:", df.isnull().sum().sum())
print("Duplicates:", df.duplicated().sum())
# Out:
# Rows: 1002
# Columns: 15
# Missing Values: 0
# Duplicates: 0

# %% [markdown]
# ## CLEANED DATA FILE

# %%
df.to_csv("Cleaned Ecommerce Dataset.csv", index=False)

# %% [markdown]
# ## BEFORE & AFTER DATA COMPARISON

# %%
comparison = pd.DataFrame({
    "Metric": ["Rows", "Columns", "Missing Values", "Duplicate Rows"],
    "Before": [1010, 14, 160, 8],
    "After": [
        df.shape[0],
        df.shape[1],
        df.isnull().sum().sum(),
        df.duplicated().sum()
    ]
})

comparison
# Out:
#            Metric  Before  After
# 0            Rows    1010   1002
# 1         Columns      14     15
# 2  Missing Values     160      0
# 3  Duplicate Rows       8      0

# %% [markdown]
# ## THANK YOU
# Hello Team,
# I have completed and submitted Task 3 – Data Cleaning & Manipulation using Python (Pandas & NumPy). Kindly evaluate my submission and provide feedback. Thank you!
